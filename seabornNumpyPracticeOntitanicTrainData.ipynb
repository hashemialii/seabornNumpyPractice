# %%
import pandas as pd
from IPython.display import Image
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline


import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.__version__
# Out:
# '0.11.2'

# %% [markdown]
# # check the 'train' data

# %%
Image(url= "https://media.npr.org/assets/img/2012/03/29/titanic_custom-fc6a03aedd8e562d780ecf9b9a8a947d4dcbf163-s1100-c50.jpg")
# Out:
# <img src="https://media.npr.org/assets/img/2012/03/29/titanic_custom-fc6a03aedd8e562d780ecf9b9a8a947d4dcbf163-s1100-c50.jpg"/>

# %%
data_train = pd.read_csv('train.csv')

# %%
data_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Data Dictionary
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# First five people on the list

# %%
data_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
#  Last five people on the list

# %%
data_train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# Give us perspective on our data

# %%
data_train.shape
# Out:
# (891, 12)

# %%
data_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# To check the number of nulls in each column

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 891 entries, 0 to 890
#
# Data columns (total 12 columns):
#
#  #   Column       Non-Null Count  Dtype
#
# ---  ------       --------------  -----
#
#  0   PassengerId  891 non-null    int64
#
#  1   Survived     891 non-null    int64
#
#  2   Pclass       891 non-null    int64
#
#  3   Name         891 non-null    object
#
#  4   Sex          891 non-null    object
#
#  5   Age          714 non-null    float64
#
#  6   SibSp        891 non-null    int64
#
#  7   Parch        891 non-null    int64
#
#  8   Ticket       891 non-null    object
#
#  9   Fare         891 non-null    float64
#
#  10  Cabin        204 non-null    object
#
#  11  Embarked     889 non-null    object
#
# dtypes: float64(2), int64(5), object(5)
#
# memory usage: 83.7+ KB

# %% [markdown]
# For random data

# %%
df = pd.DataFrame(data_train)
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 464          465         0       3  Maisner, Mr. Simon  male   NaN      0
# 321          322         0       3    Danoff, Mr. Yoto  male  27.0      0
# 500          501         0       3    Calic, Mr. Petar  male  17.0      0
#
#      Parch    Ticket    Fare Cabin Embarked
# 464      0  A/S 2816  8.0500   NaN        S
# 321      0    349219  7.8958   NaN        S
# 500      0    315086  8.6625   NaN        S

# %% [markdown]
# Percentage of people who survived or died

# %%
data_train['Survived'].value_counts(normalize=True)* 100
# Out:
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %%
sns.displot(data_train, x="Survived", bins=2)
sns.catplot(x="Survived", kind="count", data=data_train)

# %% [markdown]
# Most people was dead

# %%
sns.pairplot(data_train, hue='Survived',palette='coolwarm')

# %%
data_train['Sex'].value_counts(normalize=True)* 100
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64

# %%
a = sns.displot(data_train, x="Sex")
a.set_xticklabels(rotation=45) # Rotating axis labels in matplotlib and seaborn
sns.catplot(x="Sex", kind="count", data=data_train)

# %% [markdown]
# The number of men was twice as many as women

# %%
data_train['SibSp'].value_counts(normalize=True)* 100
# Out:
# 0    68.237935
# 1    23.456790
# 2     3.142536
# 4     2.020202
# 3     1.795735
# 8     0.785634
# 5     0.561167
# Name: SibSp, dtype: float64

# %%
sns.displot(data_train, x="SibSp", bins=3)
sns.displot(data_train, x="SibSp", kind="kde")
sns.catplot(x="SibSp", kind="count", data=data_train)

# %% [markdown]
# Most of the passengers had few siblings and spouses

# %%
data_train['Parch'].value_counts(normalize=True)* 100
# Out:
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 5     0.561167
# 3     0.561167
# 4     0.448934
# 6     0.112233
# Name: Parch, dtype: float64

# %%
sns.displot(data_train, x="Parch", bins=3)
sns.displot(data_train, x="Parch", kind="kde")
sns.catplot(x="Parch", kind="count", data=data_train)

# %% [markdown]
# Most of the passengers had few parents and children

# %%
data_train['Embarked'].value_counts(normalize=True)* 100
# Out:
# S    72.440945
# C    18.897638
# Q     8.661417
# Name: Embarked, dtype: float64

# %%
sns.displot(data_train, x="Embarked")
sns.catplot(x="Embarked", kind="count", data=data_train)

# %% [markdown]
# Most people boarded the ship from Port S

# %%
sns.displot(data_train, x="Age")
sns.displot(data_train, x="Age", kind="kde")
sns.catplot(x="Age", kind="count", data=data_train)

# %% [markdown]
# Most people were between 18 and 35 years old

# %%
sns.displot(data_train, x="Fare")
sns.displot(data_train, x="Fare", kind="kde")

# %% [markdown]
# Most people have paid up to $100
#
# It is easy to see outliers

# %% [markdown]
# # To examine qualitative variables

# %%
data_train[['Survived', 'Pclass']].value_counts(normalize=True)* 100
# Out:
# Survived  Pclass
# 0         3         41.750842
# 1         1         15.263749
#           3         13.355780
# 0         2         10.886644
# 1         2          9.764310
# 0         1          8.978676
# dtype: float64

# %%
sns.catplot(x="Survived",hue='Pclass', kind="count",palette="ch:.25", data=data_train)
sns.displot(data_train, x="Survived",hue='Pclass', kind="kde", fill="True")

# %% [markdown]
# Most of the people who died were from pclass 3

# %%
data_train[['Survived', 'Sex']].value_counts(normalize=True)* 100
# Out:
# Survived  Sex
# 0         male      52.525253
# 1         female    26.150393
#           male      12.233446
# 0         female     9.090909
# dtype: float64

# %%
sns.catplot(x="Survived",hue='Sex', kind="count",palette="ch:.25", data=data_train)
sns.displot(data_train, x="Survived",hue='Sex', kind="kde", fill="True")

# %% [markdown]
# Men died more than women

# %%
data_train[['Survived', 'SibSp']].value_counts(normalize=True)* 100
# Out:
# Survived  SibSp
# 0         0        44.668911
# 1         0        23.569024
#           1        12.570146
# 0         1        10.886644
#           2         1.683502
#           4         1.683502
# 1         2         1.459035
# 0         3         1.346801
#           8         0.785634
#           5         0.561167
# 1         3         0.448934
#           4         0.336700
# dtype: float64

# %%
sns.catplot(x="Survived",hue='SibSp', kind="count",palette="ch:.25", data=data_train)
sns.displot(data_train, x="Survived",hue='SibSp', kind="kde", fill="True")

# %%
data_train[['Survived', 'Parch']].value_counts(normalize=True)* 100
# Out:
# Survived  Parch
# 0         0        49.943883
# 1         0        26.150393
#           1         7.295174
# 0         1         5.948373
#           2         4.489338
# 1         2         4.489338
# 0         4         0.448934
#           5         0.448934
# 1         3         0.336700
# 0         3         0.224467
#           6         0.112233
# 1         5         0.112233
# dtype: float64

# %%
sns.catplot(x="Survived",hue='Parch', kind="count",palette="ch:.25", data=data_train)
sns.displot(data_train, x="Survived",hue='Parch', kind="kde", fill="True")

# %% [markdown]
# Most of the people who died had no family

# %%
data_train[['Survived', 'Embarked']].value_counts(normalize=True)* 100
# Out:
# Survived  Embarked
# 0         S           48.031496
# 1         S           24.409449
#           C           10.461192
# 0         C            8.436445
#           Q            5.286839
# 1         Q            3.374578
# dtype: float64

# %%
sns.catplot(x="Survived",hue='Embarked', kind="count",palette="ch:.25", data=data_train)
sns.displot(data_train, x="Survived",hue='Embarked', kind="kde", fill="True")

# %% [markdown]
# Most of them who died boarded the ship from Port S

# %% [markdown]
# # Story telling

# %%
pd.crosstab(data_train.Sex, data_train.Survived, normalize='index')* 100
# Out:
# Survived          0          1
# Sex
# female    25.796178  74.203822
# male      81.109185  18.890815

# %%
sns.catplot(x="Survived",hue='Sex', kind="count",palette="ch:.25", data=data_train)

# %%
pd.crosstab(data_train.Sex, data_train.Survived, normalize='index').plot.bar(rot=20)
# Rotating axis labels in pundas
# Out:
# <AxesSubplot:xlabel='Sex'>

# %% [markdown]
# More men died than women

# %%
pd.crosstab(data_train.Sex, data_train.Survived, normalize='columns')* 100
# Out:
# Survived          0          1
# Sex
# female    14.754098  68.128655
# male      85.245902  31.871345

# %%
sns.catplot(x="Sex", kind="count", data=data_train)

# %%
sns.catplot(x="Sex",hue='Survived', kind="count",palette="ch:.25", data=data_train)

# %% [markdown]
# 85% of men and 15% of women died

# %%
pd.crosstab(data_train.Pclass, data_train.Survived, normalize='index')* 100
# Out:
# Survived          0          1
# Pclass
# 1         37.037037  62.962963
# 2         52.717391  47.282609
# 3         75.763747  24.236253

# %%
sns.catplot(x="Survived",hue='Pclass', kind="count",palette="ch:.25", data=data_train)

# %%
pd.crosstab(data_train.Pclass, data_train.Survived, normalize='columns')* 100
# Out:
# Survived          0          1
# Pclass
# 1         14.571949  39.766082
# 2         17.668488  25.438596
# 3         67.759563  34.795322

# %%
sns.catplot(x="Pclass",hue='Survived', kind="count",palette="ch:.25", data=data_train)

# %%
pd.crosstab(data_train.SibSp, data_train.Survived, normalize='index')* 100
# Out:
# Survived           0          1
# SibSp
# 0          65.460526  34.539474
# 1          46.411483  53.588517
# 2          53.571429  46.428571
# 3          75.000000  25.000000
# 4          83.333333  16.666667
# 5         100.000000   0.000000
# 8         100.000000   0.000000

# %%
pd.crosstab(data_train.SibSp, data_train.Survived, normalize='columns')* 100
# Out:
# Survived          0          1
# SibSp
# 0         72.495446  61.403509
# 1         17.668488  32.748538
# 2          2.732240   3.801170
# 3          2.185792   1.169591
# 4          2.732240   0.877193
# 5          0.910747   0.000000
# 8          1.275046   0.000000

# %%
pd.crosstab(data_train.Parch, data_train.Survived, normalize='index')* 100
# Out:
# Survived           0          1
# Parch
# 0          65.634218  34.365782
# 1          44.915254  55.084746
# 2          50.000000  50.000000
# 3          40.000000  60.000000
# 4         100.000000   0.000000
# 5          80.000000  20.000000
# 6         100.000000   0.000000

# %%
pd.crosstab(data_train.Parch, data_train.Survived, normalize='columns')* 100
# Out:
# Survived          0          1
# Parch
# 0         81.056466  68.128655
# 1          9.653916  19.005848
# 2          7.285974  11.695906
# 3          0.364299   0.877193
# 4          0.728597   0.000000
# 5          0.728597   0.292398
# 6          0.182149   0.000000

# %%
pd.crosstab(data_train.Embarked, data_train.Survived, normalize='index')* 100
# Out:
# Survived          0          1
# Embarked
# C         44.642857  55.357143
# Q         61.038961  38.961039
# S         66.304348  33.695652

# %%
pd.crosstab(data_train.Embarked, data_train.Survived, normalize='columns')* 100
# Out:
# Survived          0          1
# Embarked
# C         13.661202  27.352941
# Q          8.561020   8.823529
# S         77.777778  63.823529

# %% [markdown]
# # Fillter on data

# %%
above_60_years = data_train[data_train.Age >= 60]
above_60_years
# Out:
#      PassengerId  Survived  Pclass  \
# 33            34         0       2
# 54            55         0       1
# 96            97         0       1
# 116          117         0       3
# 170          171         0       1
# 252          253         0       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 483          484         1       3
# 493          494         0       1
# 545          546         0       1
# 555          556         0       1
# 570          571         1       2
# 587          588         1       1
# 625          626         0       1
# 630          631         1       1
# 672          673         0       2
# 684          685         0       2
# 694          695         0       1
# 745          746         0       1
# 829          830         1       1
# ...

# %%
above_60_years.shape
# Out:
# (26, 12)

# %%
above_150_fare = data_train[data_train.Fare >= 150]
above_150_fare
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 268          269         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 311          312         1       1
# 318          319         1       1
# 332          333         0       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 498          499         0       1
# 527          528         0       1
# 557          558         0       1
# 609          610         1       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 708          709         1       1
# 716          717         1       1
# 730          731         1       1
# ...

# %%
above_150_fare.shape
# Out:
# (29, 12)

# %%
above_60_years['Survived'].value_counts()
# Out:
# 0    19
# 1     7
# Name: Survived, dtype: int64

# %%
above_150_fare['Survived'].value_counts()
# Out:
# 1    20
# 0     9
# Name: Survived, dtype: int64

# %%
data_train[data_train.Age >= 60][['Survived', 'Age', 'Pclass', 'Fare']].sort_values('Fare')
# Out:
#      Survived   Age  Pclass      Fare
# 326         0  61.0       3    6.2375
# 280         0  65.0       3    7.7500
# 116         0  70.5       3    7.7500
# 851         0  74.0       3    7.7750
# 483         1  63.0       3    9.5875
# 33          0  66.0       2   10.5000
# 672         0  70.0       2   10.5000
# 570         1  62.0       2   10.5000
# 545         0  64.0       1   26.0000
# 694         0  60.0       1   26.5500
# 456         0  65.0       1   26.5500
# 252         0  62.0       1   26.5500
# 555         0  62.0       1   26.5500
# 630         1  80.0       1   30.0000
# 625         0  61.0       1   32.3208
# 170         0  61.0       1   33.5000
# 96          0  71.0       1   34.6542
# 684         0  60.0       2   39.0000
# 493         0  71.0       1   49.5042
# 54          0  65.0       1   61.9792
# 745         0  70.0       1   71.0000
# 366         1  60.0       1   75.2500
# 275         1  63.0       1   77.9583
# 587         1  60.0       1   79.2000
# ...

# %%
data_train[data_train.Fare >= 150][['Survived', 'Age', 'Pclass', 'Fare']].sort_values('Fare')
# Out:
#      Survived    Age  Pclass      Fare
# 708         1  22.00       1  151.5500
# 498         0  25.00       1  151.5500
# 297         0   2.00       1  151.5500
# 305         1   0.92       1  151.5500
# 332         0  38.00       1  153.4625
# 609         1  40.00       1  153.4625
# 268         1  58.00       1  153.4625
# 318         1  31.00       1  164.8667
# 856         1  45.00       1  164.8667
# 689         1  15.00       1  211.3375
# 779         1  43.00       1  211.3375
# 730         1  29.00       1  211.3375
# 377         0  27.00       1  211.5000
# 527         0    NaN       1  221.7792
# 716         1  38.00       1  227.5250
# 380         1  42.00       1  227.5250
# 557         0    NaN       1  227.5250
# 700         1  18.00       1  227.5250
# 299         1  50.00       1  247.5208
# 118         0  24.00       1  247.5208
# 742         1  21.00       1  262.3750
# 311         1  18.00       1  262.3750
# 27          0  19.00       1  263.0000
# ...

# %%
above_60_years[above_60_years.Fare >= 150]
# Out:
#      PassengerId  Survived  Pclass               Name   Sex   Age  SibSp  \
# 438          439         0       1  Fortune, Mr. Mark  male  64.0      1
#
#      Parch Ticket   Fare        Cabin Embarked
# 438      4  19950  263.0  C23 C25 C27        S

# %%
data_train[ ( data_train.Fare >= 150 ) & ( data_train.Age >= 60) ]
# Out:
#      PassengerId  Survived  Pclass               Name   Sex   Age  SibSp  \
# 438          439         0       1  Fortune, Mr. Mark  male  64.0      1
#
#      Parch Ticket   Fare        Cabin Embarked
# 438      4  19950  263.0  C23 C25 C27        S

# %%
data_train[ ( data_train.Fare >= 150 ) & ( data_train.Age >= 60) ][['Age', 'Sex', 'Pclass']]
# Out:
#       Age   Sex  Pclass
# 438  64.0  male       1

# %% [markdown]
# # Null

# %%
data_train[data_train.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data_train[data_train.Age.isnull()][['Sex', 'Survived', 'Age', 'Pclass']][0:5]
# Out:
#        Sex  Survived  Age  Pclass
# 5     male         0  NaN       3
# 17    male         1  NaN       2
# 19  female         1  NaN       3
# 26    male         0  NaN       3
# 28  female         1  NaN       3

# %% [markdown]
# # Not null

# %%
data_train[-data_train.Age.isnull()][['Sex', 'Survived', 'Age', 'Pclass']][0:5]
# Out:
#       Sex  Survived   Age  Pclass
# 0    male         0  22.0       3
# 1  female         1  38.0       1
# 2  female         1  26.0       3
# 3  female         1  35.0       1
# 4    male         0  35.0       3

# %%
data_train[data_train.Age.notnull()][['Sex', 'Survived', 'Age', 'Pclass']][0:5]
# Out:
#       Sex  Survived   Age  Pclass
# 0    male         0  22.0       3
# 1  female         1  38.0       1
# 2  female         1  26.0       3
# 3  female         1  35.0       1
# 4    male         0  35.0       3

# %% [markdown]
# # Examination of quantitative and qualitative variables (groupby)

# %%
data_train.groupby('Pclass')['Age'].mean().reset_index()
# Out:
#    Pclass        Age
# 0       1  38.233441
# 1       2  29.877630
# 2       3  25.140620

# %%
sns.displot(data_train, x="Age", hue='Pclass',kind="kde", fill="True")
sns.catplot(x="Pclass", y="Age", data=data_train)
sns.catplot(x="Pclass", y="Age", jitter=False, data=data_train)
sns.catplot(x="Pclass", y="Age", kind="swarm", data=data_train)
sns.catplot(x="Pclass", y="Age", kind="swarm", data=data_train)
sns.catplot(x="Pclass", y="Age", kind="box", data=data_train)

# %%
data_train.groupby('Pclass')['Fare'].mean().reset_index()
# Out:
#    Pclass       Fare
# 0       1  84.154687
# 1       2  20.662183
# 2       3  13.675550

# %%
sns.displot(data_train, x="Fare", hue='Pclass',kind="kde", fill="True")
sns.catplot(x="Pclass", y="Fare", data=data_train)
sns.catplot(x="Pclass", y="Fare", jitter=False, data=data_train)
sns.catplot(x="Pclass", y="Fare", kind="swarm", data=data_train)
sns.catplot(x="Pclass", y="Fare", kind="swarm", data=data_train)
sns.catplot(x="Pclass", y="Fare", kind="box", data=data_train)

# %%
sns.relplot(x="Age", y="Fare", data=data_train)
sns.relplot(x="Age", y="Fare", kind="line", data=data_train)

# %%
sns.regplot(x="Age", y="Fare", data=data_train)
sns.lmplot(x="Age", y="Fare", data=data_train)

# %%
data_train.groupby(['Pclass'],as_index=False)['Fare', 'Age'].mean().sort_values(by='Fare', ascending=True)
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_218312\3537287027.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   data_train.groupby(['Pclass'],as_index=False)['Fare', 'Age'].mean().sort_values(by='Fare', ascending=True)
#    Pclass       Fare        Age
# 2       3  13.675550  25.140620
# 1       2  20.662183  29.877630
# 0       1  84.154687  38.233441

# %%
sns.relplot(x="Age", y="Fare", hue="Pclass", data=data_train)
sns.relplot(x="Age", y="Fare", hue="Pclass", kind="line", data=data_train)
sns.relplot(x="Age", y="Fare", size="Pclass", data=data_train)

# %%
data_train.groupby(['Pclass', 'Sex'])['Age'].mean().reset_index()
# Out:
#    Pclass     Sex        Age
# 0       1  female  34.611765
# 1       1    male  41.281386
# 2       2  female  28.722973
# 3       2    male  30.740707
# 4       3  female  21.750000
# 5       3    male  26.507589

# %%
sns.catplot(x="Pclass", y="Age", hue="Sex", kind="swarm", data=data_train)
sns.catplot(x="Pclass", y="Age", hue="Sex", kind="box", data=data_train)
sns.catplot(x="Pclass", y="Age", hue="Sex", kind="boxen", data=data_train)
sns.catplot(x="Pclass", y="Age", hue="Sex", kind="violin", data=data_train)
sns.catplot(x="Pclass", y="Age", hue="Sex", kind="bar", data=data_train)
sns.catplot(x="Pclass", y="Age", hue="Sex", kind="point", data=data_train)

# %%
g = sns.FacetGrid(data_train, col="Pclass",  row="Sex")
g.map_dataframe(sns.histplot, x="Age")

# %%
data_train.groupby(['Pclass', 'Sex'],as_index=False)['Fare', 'Age'].mean()
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_218312\788152543.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   data_train.groupby(['Pclass', 'Sex'],as_index=False)['Fare', 'Age'].mean()
#    Pclass     Sex        Fare        Age
# 0       1  female  106.125798  34.611765
# 1       1    male   67.226127  41.281386
# 2       2  female   21.970121  28.722973
# 3       2    male   19.741782  30.740707
# 4       3  female   16.118810  21.750000
# 5       3    male   12.661633  26.507589

# %%
sns.relplot(x="Age", y="Fare", hue="Pclass", style="Sex", data=data_train)
sns.relplot(x="Age", y="Fare", hue="Pclass", style="Sex", kind="line", data=data_train)
sns.relplot(x="Age", y="Fare", hue="Pclass",col="Sex", data=data_train)

# %%
g = sns.FacetGrid(data_train, col="Pclass", hue="Sex")
g.map_dataframe(sns.scatterplot, x="Age", y="Fare")
g.set_axis_labels("age", "fare")
g.add_legend()

# %%
above_60_years.groupby(['Pclass', 'Sex'],as_index=False)['Fare', 'Age'].mean()
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_218312\511896722.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   above_60_years.groupby(['Pclass', 'Sex'],as_index=False)['Fare', 'Age'].mean()
#    Pclass     Sex       Fare        Age
# 0       1  female  77.736100  61.666667
# 1       1    male  56.239886  65.428571
# 2       2    male  17.625000  64.500000
# 3       3  female   9.587500  63.000000
# 4       3    male   7.378125  67.625000

# %%
above_150_fare.groupby(['Pclass', 'Sex'],as_index=False)['Fare', 'Age'].mean()
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_218312\572165343.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   above_150_fare.groupby(['Pclass', 'Sex'],as_index=False)['Fare', 'Age'].mean()
#    Pclass     Sex       Fare        Age
# 0       1  female  222.02610  30.473684
# 1       1    male  276.39959  30.490000

# %%
data_train.groupby(['SibSp'],as_index=False)['Fare', 'Age'].mean()
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_218312\1440778532.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   data_train.groupby(['SibSp'],as_index=False)['Fare', 'Age'].mean()
#    SibSp       Fare        Age
# 0      0  25.692028  31.397558
# 1      1  44.147370  30.089727
# 2      2  51.753718  22.620000
# 3      3  68.908862  13.916667
# 4      4  31.855556   7.055556
# 5      5  46.900000  10.200000
# 6      8  69.550000        NaN

# %%
sns.relplot(x="Age", y="Fare", hue="SibSp", data=data_train)
sns.relplot(x="Age", y="Fare", hue="SibSp", kind="line", data=data_train)
sns.relplot(x="Age", y="Fare", size="SibSp", data=data_train)

# %%
data_train.groupby(['Parch'],as_index=False)['Fare', 'Age'].mean()
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_218312\2053436236.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   data_train.groupby(['Parch'],as_index=False)['Fare', 'Age'].mean()
#    Parch       Fare        Age
# 0      0  25.586774  32.178503
# 1      1  46.778180  24.422000
# 2      2  64.337604  17.216912
# 3      3  25.951660  33.200000
# 4      4  84.968750  44.500000
# 5      5  32.550000  39.200000
# 6      6  46.900000  43.000000

# %%
sns.relplot(x="Age", y="Fare", hue="Parch", data=data_train)
sns.relplot(x="Age", y="Fare", hue="Parch", kind="line", data=data_train)
sns.relplot(x="Age", y="Fare", size="Parch", data=data_train)

# %%
data_train.groupby(['Embarked'],as_index=False)['Fare', 'Age'].mean()
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_218312\2447322496.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   data_train.groupby(['Embarked'],as_index=False)['Fare', 'Age'].mean()
#   Embarked       Fare        Age
# 0        C  59.954144  30.814769
# 1        Q  13.276030  28.089286
# 2        S  27.079812  29.445397

# %%
sns.relplot(x="Age", y="Fare", hue="Embarked", data=data_train)
sns.relplot(x="Age", y="Fare", hue="Embarked", kind="line", data=data_train)
sns.relplot(x="Age", y="Fare", size="Embarked", data=data_train)

# %%
data_train.groupby(['Survived', 'Sex'],as_index=False)['Fare', 'Age'].mean()
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_218312\2941945363.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   data_train.groupby(['Survived', 'Sex'],as_index=False)['Fare', 'Age'].mean()
#    Survived     Sex       Fare        Age
# 0         0  female  23.024385  25.046875
# 1         0    male  21.960993  31.618056
# 2         1  female  51.938573  28.847716
# 3         1    male  40.821484  27.276022

# %%
g = sns.FacetGrid(data_train, col="Survived", hue="Sex")
g.map_dataframe(sns.scatterplot, x="Age", y="Fare")
g.add_legend()

# %%
sns.relplot(x="Age", y="Fare", hue="Survived", style="Sex", data=data_train)
sns.relplot(x="Age", y="Fare", hue="Survived", style="Sex", kind="line", data=data_train)
sns.relplot(x="Age", y="Fare", hue="Survived",col="Sex", data=data_train)

# %%
data_train.groupby(['Survived', 'Sex'],as_index=False)['Fare', 'Age'].mean().sort_values(by='Age', ascending=False)
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_218312\1767421828.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   data_train.groupby(['Survived', 'Sex'],as_index=False)['Fare', 'Age'].mean().sort_values(by='Age', ascending=False)
#    Survived     Sex       Fare        Age
# 1         0    male  21.960993  31.618056
# 2         1  female  51.938573  28.847716
# 3         1    male  40.821484  27.276022
# 0         0  female  23.024385  25.046875

# %%
data_train.groupby(['Survived', 'Pclass'],as_index=False)['Fare', 'Age'].mean()
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_218312\984402881.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   data_train.groupby(['Survived', 'Pclass'],as_index=False)['Fare', 'Age'].mean()
#    Survived  Pclass       Fare        Age
# 0         0       1  64.684007  43.695312
# 1         0       2  19.412328  33.544444
# 2         0       3  13.669364  26.555556
# 3         1       1  95.608029  35.368197
# 4         1       2  22.055700  25.901566
# 5         1       3  13.694887  20.646118

# %%
g = sns.FacetGrid(data_train, col="Survived", hue="Pclass")
g.map_dataframe(sns.scatterplot, x="Age", y="Fare")
g.add_legend()

# %%
sns.relplot(x="Age", y="Fare", hue="Survived", style="Pclass", data=data_train)
sns.relplot(x="Age", y="Fare", hue="Survived", style="Pclass", kind="line", data=data_train)
sns.relplot(x="Age", y="Fare", hue="Survived",col="Pclass", data=data_train)
